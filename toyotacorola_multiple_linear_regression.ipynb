# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/suraj/Desktop/ExcelR/Assignment 5 multi linear regression/ToyotaCorolla.csv" , encoding=("ISO-8859-1"), low_memory=False)
data.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
data.drop(data.iloc[: , 18:] , inplace= True, axis=1)
data
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color   Color  \
# ...

# %%
data.drop(data.columns[[0,1,4,5,7,9,10,11,14]], axis=1, inplace=True)
data.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
data.shape
# Out:
# (1436, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
data1=data.rename({"Age_08_04":"age"},axis=1)

# %%
data1
# Out:
#       Price  age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500   69  20544   86  1300      3      5             69    1025
# 1432  10845   72  19000   86  1300      3      5             69    1015
# 1433   8500   71  17016   86  1300      3      5             69    1015
# 1434   7250   70  16916   86  1300      3      5             69    1015
# 1435   6950   76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
data1[data1.duplicated()]
# Out:
#      Price  age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 113  24950    8  13253  116  2000      5      5            234    1320

# %%
data2=data1.drop_duplicates().reset_index(drop=True)

# %%
data2
# Out:
#       Price  age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1430   7500   69  20544   86  1300      3      5             69    1025
# 1431  10845   72  19000   86  1300      3      5             69    1015
# 1432   8500   71  17016   86  1300      3      5             69    1015
# 1433   7250   70  16916   86  1300      3      5             69    1015
# 1434   6950   76      1  110  1600      5      5             19    1114
#
# [1435 rows x 9 columns]

# %%
data2.describe()
# Out:
#               Price          age             KM           HP            cc  \
# count   1435.000000  1435.000000    1435.000000  1435.000000   1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986   1576.560976
# std     3608.732978    18.563312   37491.094553    14.981408    424.387533
# min     4350.000000     1.000000       1.000000    69.000000   1300.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000   1600.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000   1600.000000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.000000
#
#              Doors        Gears  Quarterly_Tax       Weight
# count  1435.000000  1435.000000    1435.000000  1435.000000
# mean      4.032753     5.026481      87.020209  1072.287108
# std       0.952667     0.188575      40.959588    52.251882
# ...

# %%
data2.corr()
# Out:
#                   Price       age        KM        HP        cc     Doors  \
# Price          1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604
# age           -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929
# KM            -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193
# HP             0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803
# cc             0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254
# Doors          0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000
# Gears          0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101
# Quarterly_Tax  0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353
# Weight         0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063831       0.211508  0.575869
# age           -0.005629      -0.193319 -0.466484
# KM             0.014890       0.283312 -0.023969
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#sns.pairplot(data2)

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
model=smf.ols("Price~age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=data2).fit()

# %%
model.params
# Out:
# Intercept       -5472.540368
# age              -121.713891
# KM                 -0.020737
# HP                 31.584612
# cc                 -0.118558
# Doors              -0.920189
# Gears             597.715894
# Quarterly_Tax       3.858805
# Weight             16.855470
# dtype: float64

# %%
print(model.tvalues,'\n',model.pvalues)
# Out:
# Intercept        -3.875273
# age             -46.551876
# KM              -16.552424
# HP               11.209719
# cc               -1.316436
# Doors            -0.023012
# Gears             3.034563
# Quarterly_Tax     2.944198
# Weight           15.760663
# dtype: float64
#  Intercept         1.113392e-04
# age              1.879217e-288
# KM                1.994713e-56
# HP                5.211155e-28
# cc                1.882393e-01
# Doors             9.816443e-01
# Gears             2.452430e-03
# Quarterly_Tax     3.290363e-03
# Weight            1.031118e-51
# dtype: float64

# %%
(model.rsquared,model.rsquared_adj)
# Out:
# (0.8625200256947, 0.8617487495415146)

# %%
model_c=smf.ols("Price~cc",data=data2).fit()

# %%
model_c.params
# Out:
# Intercept    9053.536789
# cc              1.057605
# dtype: float64

# %%
print(model_c.tvalues,'\n',model_c.pvalues)
# Out:
# Intercept    24.879592
# cc            4.745039
# dtype: float64
#  Intercept    7.236022e-114
# cc            2.292856e-06
# dtype: float64

# %%
model_d=smf.ols("Price~Doors",data=data2).fit()

# %%
print(model_d.tvalues,'\n',model_d.pvalues)
# Out:
# Intercept    19.421546
# Doors         7.070520
# dtype: float64
#  Intercept    8.976407e-75
# Doors        2.404166e-12
# dtype: float64

# %%
model_cd=smf.ols("Price~cc+Doors",data=data2).fit()

# %%
print(model_cd.tvalues,'\n',model_cd.pvalues)
# Out:
# Intercept    12.786341
# cc            4.268006
# Doors         6.752236
# dtype: float64
#  Intercept    1.580945e-35
# cc           2.101878e-05
# Doors        2.109558e-11
# dtype: float64

# %%
rsq_age=smf.ols('age~KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=data2).fit().rsquared
vif_age=1/(1-rsq_age)

rsq_KM=smf.ols('KM~age+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=data2).fit().rsquared
vif_KM=1/(1-rsq_KM)

rsq_HP=smf.ols('HP~age+KM+cc+Doors+Gears+Quarterly_Tax+Weight',data=data2).fit().rsquared
vif_HP=1/(1-rsq_HP)

rsq_CC=smf.ols('cc~age+KM+HP+Doors+Gears+Quarterly_Tax+Weight',data=data2).fit().rsquared
vif_CC=1/(1-rsq_CC)

rsq_DR=smf.ols('Doors~age+KM+HP+cc+Gears+Quarterly_Tax+Weight',data=data2).fit().rsquared
vif_DR=1/(1-rsq_DR)

rsq_GR=smf.ols('Gears~age+KM+HP+cc+Doors+Quarterly_Tax+Weight',data=data2).fit().rsquared
vif_GR=1/(1-rsq_GR)

rsq_QT=smf.ols('Quarterly_Tax~age+KM+HP+cc+Doors+Gears+Weight',data=data2).fit().rsquared
vif_QT=1/(1-rsq_QT)

rsq_WT=smf.ols('Weight~age+KM+HP+cc+Doors+Gears+Quarterly_Tax',data=data2).fit().rsquared
vif_WT=1/(1-rsq_WT)

# %%
d1={'Variables':['Age','KM','HP','CC','Doors','Gears','QT','Weight'],
    'Vif':[vif_age,vif_KM,vif_HP,vif_CC,vif_DR,vif_GR,vif_QT,vif_WT]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       Age  1.876236
# 1        KM  1.757178
# 2        HP  1.419180
# 3        CC  1.163470
# 4     Doors  1.155890
# 5     Gears  1.098843
# 6        QT  2.295375
# 7    Weight  2.487180

# %%
list(np.where(model.resid>15000))
# Out:
# [array([], dtype=int64)]

# %%
list(np.where(model.resid<-15000))
# Out:
# [array([], dtype=int64)]

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([7.22221054e-03, 3.94547973e-03, 5.44224039e-03, ...,
#        8.04110550e-07, 6.99854767e-04, 1.08408002e-02])

# %%
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data2)),np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c) , np.max(c))
# Out:
# (80, 78.72950582247482)

# %%
from statsmodels.graphics.regressionplots import influence_plot

# %%
fig,ax=plt.subplots(figsize=(20,20))
fig=influence_plot(model,ax = ax)

# %%
k=data2.shape[1]
n=data2.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
data2[data2.index.isin([80])]
# Out:
#     Price  age     KM   HP     cc  Doors  Gears  Quarterly_Tax  Weight
# 80  18950   25  20019  110  16000      5      5            100    1180

# %%
data3=data2.copy()
data3
# Out:
#       Price  age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1430   7500   69  20544   86  1300      3      5             69    1025
# 1431  10845   72  19000   86  1300      3      5             69    1015
# 1432   8500   71  17016   86  1300      3      5             69    1015
# 1433   7250   70  16916   86  1300      3      5             69    1015
# 1434   6950   76      1  110  1600      5      5             19    1114
#
# [1435 rows x 9 columns]

# %%
data4=data3.drop(data3.index[[80]],axis=0).reset_index(drop=True)
data4
# Out:
#       Price  age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1429   7500   69  20544   86  1300      3      5             69    1025
# 1430  10845   72  19000   86  1300      3      5             69    1015
# 1431   8500   71  17016   86  1300      3      5             69    1015
# 1432   7250   70  16916   86  1300      3      5             69    1015
# 1433   6950   76      1  110  1600      5      5             19    1114
#
# [1434 rows x 9 columns]

# %%
 while np.max(c)>0.5 :
    model=smf.ols('Price~age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=data4).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data4=data4.drop(data4.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data4
else:
    final_model=smf.ols('Price~age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=data4).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8882395145171204

# %%
final_model.rsquared
# Out:
# 0.8882395145171204

# %%
data4
# Out:
#       Price  age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1426   7500   69  20544   86  1300      3      5             69    1025
# 1427  10845   72  19000   86  1300      3      5             69    1015
# 1428   8500   71  17016   86  1300      3      5             69    1015
# 1429   7250   70  16916   86  1300      3      5             69    1015
# 1430   6950   76      1  110  1600      5      5             19    1114
#
# [1431 rows x 9 columns]

# %%
new_data=pd.DataFrame({'age':23,"KM":40000,"HP":86,"cc":1600,"Doors":4,"Gears":4,"Quarterly_Tax":19,"Weight":1170},index=[0])
new_data
# Out:
#    age     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0   23  40000  86  1600      4      4             19    1170

# %%
final_model.predict(new_data)
# Out:
# 0    16654.319329
# dtype: float64

# %%
pred_y=final_model.predict(data4)
pred_y
# Out:
# 0       16345.352610
# 1       15886.635544
# 2       16328.224968
# 3       15996.318854
# 4       15883.424182
#             ...
# 1426     9161.230587
# 1427     8536.091326
# 1428     8681.531063
# 1429     8793.668694
# 1430    10860.695492
# Length: 1431, dtype: float64

# %% [markdown]
# # Actual vs predicted

# %%
plt.plot(data4.Price , label="Actual price")
plt.plot(pred_y, label="predicted price")
plt.grid(True)
legend=plt.legend()
plt.show()

# %% [markdown]
# # Lasso

# %%
x= data4.iloc[:,1:]
y= data4.iloc[:,:1]

# %%
from sklearn.model_selection import train_test_split
train_x , test_x, train_y, test_y = train_test_split(x,y,test_size=0.2, random_state=0)

# %%
from sklearn import linear_model

# %%
lasso_reg= linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.fit(train_x, train_y)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(train_x,train_y)
# Out:
# 0.8791344860831631

# %%
lasso_reg.score(test_x,test_y)
# Out:
# 0.8592009225376668

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg = Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.fit(train_x, train_y)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.score(train_x,train_y)
# Out:
# 0.889826765705515

# %%
ridge_reg.score(test_x,test_y)
# Out:
# 0.8797182815918976
